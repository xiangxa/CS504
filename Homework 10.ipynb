# %%
#Download the posted SA_Obesity_Lancet_Data xlsx formatted dataset which is posted under the lesson folder on Moodle.¶
#1- Import to pandas to create a pandas datafram

import numpy as np
import pandas as pd
data=pd.read_excel('SA_Obesity_Lancet_Data.xlsx')
data.head()
# Out:
#   Country/Region/World  ISO  Sex  Year   Mean_BMI  \
# 0         South Africa  ZAF  Men  1975  22.127209
# 1         South Africa  ZAF  Men  1976  22.218582
# 2         South Africa  ZAF  Men  1977  22.309446
# 3         South Africa  ZAF  Men  1978  22.399740
# 4         South Africa  ZAF  Men  1979  22.489756
#
#    Prevalence_BMI_over_30_obese  Prevalence_BMI_over_35_severe_obese  \
# 0                      0.023808                             0.002562
# 1                      0.024783                             0.002732
# 2                      0.025808                             0.002919
# 3                      0.026891                             0.003125
# 4                      0.028034                             0.003352
#
#    Prevalence_BMI_over_40_morbid_obese
# 0                             0.000494
# 1                             0.000532
# 2                             0.000576
# 3                             0.000625
# 4                             0.000682

# %%
#2- Display the last 10 rows/observations

data.tail(10)
# Out:
#    Country/Region/World  ISO    Sex  Year   Mean_BMI  \
# 74         South Africa  ZAF  Women  2007  28.825229
# 75         South Africa  ZAF  Women  2008  28.919270
# 76         South Africa  ZAF  Women  2009  29.010251
# 77         South Africa  ZAF  Women  2010  29.098620
# 78         South Africa  ZAF  Women  2011  29.184500
# 79         South Africa  ZAF  Women  2012  29.268313
# 80         South Africa  ZAF  Women  2013  29.350582
# 81         South Africa  ZAF  Women  2014  29.432088
# 82         South Africa  ZAF  Women  2015  29.512614
# 83         South Africa  ZAF  Women  2016  29.591921
#
#     Prevalence_BMI_over_30_obese  Prevalence_BMI_over_35_severe_obese  \
# 74                      0.357371                             0.172047
# 75                      0.363462                             0.176341
# 76                      0.369487                             0.180621
# 77                      0.375466                             0.184899
# ...

# %%
#3- Display the first two columns, Sex and Year for the rows/observations 10-25¶

data.iloc[10:25,0:2]

data[['Sex','Year']].loc[10:25,:]
# Out:
#     Sex  Year
# 10  Men  1985
# 11  Men  1986
# 12  Men  1987
# 13  Men  1988
# 14  Men  1989
# 15  Men  1990
# 16  Men  1991
# 17  Men  1992
# 18  Men  1993
# 19  Men  1994
# 20  Men  1995
# 21  Men  1996
# 22  Men  1997
# 23  Men  1998
# 24  Men  1999
# 25  Men  2000

# %%
#4- Calculate the correlation between Year and Mean_BMI and interpret the finding
data[["Year","Mean_BMI"]].corr()

# This means that the year and BMI has correlation of 0.4255, they are somewhat correlated, 
#and the increase of year  will result in the increase of mean_bmi.
# Out:
#               Year  Mean_BMI
# Year      1.000000  0.425537
# Mean_BMI  0.425537  1.000000

# %%
#5- Plot a histogram for Prevalence_BMI_over_40_morbid_obese for Women only
# %matplotlib inline 
data[data["Sex"] == "Women"]["Prevalence_BMI_over_40_morbid_obese"].plot(kind="hist")
