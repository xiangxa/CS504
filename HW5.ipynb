# %%
from mobilechelonian import Turtle
t=Turtle()
t.speed(30)
t.circle(50,360)
t.home()
t.right(90)
t.forward(100)
t.left(45)
t.forward(50)
t.backward(50)
t.right(90)
t.forward(50)
t.backward(50)
t.home()
t.right(45)
t.forward(70)
t.home()
t.right(135)
t.forward(70)
t.home
# Out:
# Turtle()
# ...
